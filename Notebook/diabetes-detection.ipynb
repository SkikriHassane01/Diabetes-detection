# %% [markdown]
# <div style ="font-family:Trebuchet MS; background-color : #f8f0fa; border-left: 5px solid #1b4332; padding: 12px; border-radius: 50px 50px;">
#     <h2 style="color: #1b4332; font-size: 48px; text-align: center;"><b> Diabetes detection
#  </b></h2>
#     <hr style="border-top: 2px solid #264653;">
#     <h3 style="font-size: 14px; color: #264653; text-align: left; "><strong> I hope this is very helpful. let's started .😊🌟</strong></h3>
#     <h2></h2>
# </div>

# %% [markdown]
# <h1 style="background-color: #12f7ff;
#            font-family: 'Trebuchet MS', sans-serif;
#            color: #000;
#            font-size: 150%;
#            text-align: center;
#            border-radius: 50px 50px;
#            padding: 20px 20px ;
#            margin: 30px 30px;
#            box-shadow: 0 0 10px rgba(18,247,255,0.6),
#     0 0 20px rgba(18,247,255,0.6),
#     0 0 30px rgba(18,247,255,0.6),
#     0 0 40px rgba(18,247,255,0.6);">
#     🔻🌟 Outline🌟🔻
# </h1>

# %% [markdown]
# <div style="background-color: #fcf8e8; /* Notepad yellow */
#            font-family: 'Times New Roman', serif; /* Classic font for note-taking */
#            color: #000;
#            font-size: 16px; /* Standard text size */
#            line-height: 1.5; /* Spacing between lines of text */
#            text-align: left;
#            border-radius: 5px;
#            padding: 20px;
#            margin: 20px;
#            width: 90%;
#            box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.2); /* Realistic shadow */
#            background-image: linear-gradient(rgba(0, 0, 0, 0.1) 1px, transparent 1px),
#                              linear-gradient(to right, rgba(0, 0, 0, 0.1) 1px, transparent 1px);
#            background-size: 100% 30px, 30px 100%; /* Size of the lines */
#            border: 1px solid #ddd; /* Border for paper edge */
#            ">
#     <ul>
#         <li>Overview about the project 📋</li>
#         <li>Import libraries 📂</li>
#         <li>Data cleaning 🧹</li>
#         <li>Exploratory Data Analysis (EDA)</li>
#         <li>Data Preprocessing for Modeling</li>
#         <li>Modeling 🧠</li>
#         <li>Save the model 🎯</li>
#     </ul>
# </div>

# %% [markdown]
# <h1 style="background-color: #12f7ff;
#            font-family: 'Trebuchet MS', sans-serif;
#            color: #000;
#            font-size: 150%;
#            text-align: center;
#            border-radius: 50px 50px;
#            padding: 20px 20px ;
#            margin: 30px 30px;
#            box-shadow: 0 0 10px rgba(18,247,255,0.6),
#     0 0 20px rgba(18,247,255,0.6),
#     0 0 30px rgba(18,247,255,0.6),
#     0 0 40px rgba(18,247,255,0.6);">
#     🔻🌟 Overview about the project 🌟🔻</h1>

# %% [markdown]
# <img style="width: 60%; height: auto; padding: 20px  auto; margin: 20px auto; display: block ; display: block; border-radius: 50px 50px;" src="https://img.freepik.com/free-photo/closeup-shot-doctor-with-rubber-gloves-taking-blood-test-from-patient_181624-56107.jpg?t=st=1720867508~exp=1720871108~hmac=319f90f661c639b306151170210bf1551257bf668b3f273ef7571bdffb0d25b4&w=996">

# %% [markdown]
# <div style="background-color: #fcf8e8; /* Notepad yellow */
#            font-family: 'Times New Roman', serif; /* Classic font for note-taking */
#            color: #000;
#            font-size: 16px; /* Standard text size */
#            line-height: 1.5; /* Spacing between lines of text */
#            text-align: left;
#            border-radius: 5px;
#            padding: 20px;
#            margin: 20px;
#            width: 90%;
#            box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.2); /* Realistic shadow */
#            background-image: linear-gradient(rgba(0, 0, 0, 0.1) 1px, transparent 1px),
#                              linear-gradient(to right, rgba(0, 0, 0, 0.1) 1px, transparent 1px);
#            background-size: 100% 30px, 30px 100%; /* Size of the lines */
#            border: 1px solid #ddd; /* Border for paper edge */
#            ">
#     <hr>
#     <p>
#         The objective is to predict based on diagnostic measurements whether a patient has diabetes or notm so the data that we will use to train our model is available on kaggle so it free to use,
#     </p>
#     <h3> Our dataset contain:</h3>
# </div>

# %% [markdown]
# <table>
#   <tr>
#     <th>Column Name</th>
#     <th>Data Type</th>
#     <th>Description</th>
#   </tr>
#   <tr>
#     <td>Pregnancies</td>
#     <td>Integer</td>
#     <td>Number of times pregnant</td>
#   </tr>
#   <tr>
#     <td>Glucose</td>
#     <td>Float</td>
#     <td>Plasma glucose concentration a 2 hours in an oral glucose tolerance test</td>
#   </tr>
#   <tr>
#     <td>BloodPressure</td>
#     <td>Float</td>
#     <td>Diastolic blood pressure (mm Hg)</td>
#   </tr>
#   <tr>
#     <td>SkinThickness</td>
#     <td>Float</td>
#     <td>Triceps skin fold thickness (mm)</td>
#   </tr>
#   <tr>
#     <td>Insulin</td>
#     <td>Float</td>
#     <td>2-Hour serum insulin (mu U/ml)</td>
#   </tr>
#   <tr>
#     <td>BMI</td>
#     <td>Float</td>
#     <td>Body mass index (weight in kg/(height in m)^2)</td>
#   </tr>
#   <tr>
#     <td>DiabetesPedigreeFunction</td>
#     <td>Float</td>
#     <td>Diabetes pedigree function</td>
#   </tr>
#   <tr>
#     <td>Age</td>
#     <td>Integer</td>
#     <td>Age (years)</td>
#   </tr>
#   <tr>
#     <td>Outcome</td>
#     <td>Integer</td>
#     <td>Class variable (0 or 1)</td>
#   </tr>
# </table>

# %% [markdown]
#  <div style="background-color: #fcf8e8; /* Notepad yellow */
#            font-family: 'Times New Roman', serif; /* Classic font for note-taking */
#            color: #000;
#            font-size: 16px; /* Standard text size */
#            line-height: 1.5; /* Spacing between lines of text */
#            text-align: left;
#            border-radius: 5px;
#            padding: 20px;
#            margin: 20px;
#            width: 90%;
#            box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.2); /* Realistic shadow */
#            background-image: linear-gradient(rgba(0, 0, 0, 0.1) 1px, transparent 1px),
#                              linear-gradient(to right, rgba(0, 0, 0, 0.1) 1px, transparent 1px);
#            background-size: 100% 30px, 30px 100%; /* Size of the lines */
#            border: 1px solid #ddd; /* Border for paper edge */
#            ">
#     <h2 style="text-align: center; color: #d4e157;">📝 Notes 📝</h2>
#     <hr>
#     <ol> pregnancy can affect glucose levels and insulin sensitivity, impacting diabetes risk.</ol>
#     <ul> Glucose is a key indicator of how the body processes sugar. High levels can indicate diabetes or prediabetes..</ul>
#     <ul> Blood pressure is a critical health indicator. Hypertension can be associated with diabetes.</ul>
#     <ul> SkinThikness measure is used to estimate body fat. Higher skinfold thickness can be an indicator of obesity, which is a risk factor for diabetes..</ul>
#     <ul> Insulin levels help in diagnosing insulin resistance and beta-cell dysfunction, which are important in diabetes management..</ul>
#     <ul>BMI is a widely used measure to classify underweight, normal weight, overweight, and obesity, which are related to diabetes risk.</ul>
#     <ul>A higher value in DiabetesPedigreeFunction indicates a stronger genetic predisposition to diabetes.</ul>
#     <ul>Age is a significant factor as the risk of developing diabetes increases with age.</ul>
#
# </div>

# %% [markdown]
# <h1 style="background-color: #12f7ff;
#            font-family: 'Trebuchet MS', sans-serif;
#            color: #000;
#            font-size: 150%;
#            text-align: center;
#            border-radius: 50px 50px;
#            padding: 20px 20px ;
#            margin: 30px 30px;
#            box-shadow: 0 0 10px rgba(18,247,255,0.6),
#     0 0 20px rgba(18,247,255,0.6),
#     0 0 30px rgba(18,247,255,0.6),
#     0 0 40px rgba(18,247,255,0.6);">
#     🔻🌟 Import libraries 🌟🔻</h1>

# %%
import numpy as np # Linear Algebra

import pandas as pd # Handling Data

import matplotlib.pyplot as plt # Visualization
import seaborn as sns # Visualization


# Feature Scaling
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler


# train test split 
from sklearn.model_selection import train_test_split

# Feature selection
from sklearn.ensemble import ExtraTreesClassifier 

#␣Performance Measures
from sklearn.metrics import classification_report, confusion_matrix 

# for modeling 
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# to get the accuracy 
from sklearn.metrics import accuracy_score

from sklearn.model_selection import cross_val_score

import optuna

import pickle

import warnings
warnings.filterwarnings('ignore')

# %%
path = "..Data/diabetes.csv"
diabetes = pd.read_csv(path)
print(f"the dataset contain",diabetes.shape[0],"rows and",diabetes.shape[1],"columns")
diabetes.head()
# Out:
# the dataset contain 768 rows and 9 columns
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# <h1 style="background-color: #12f7ff;
#            font-family: 'Trebuchet MS', sans-serif;
#            color: #000;
#            font-size: 150%;
#            text-align: center;
#            border-radius: 50px 50px;
#            padding: 20px 20px ;
#            margin: 30px 30px;
#            box-shadow: 0 0 10px rgba(18,247,255,0.6),
#     0 0 20px rgba(18,247,255,0.6),
#     0 0 30px rgba(18,247,255,0.6),
#     0 0 40px rgba(18,247,255,0.6);">
#     🔻🌟 Data Cleaning 🌟🔻</h1>

# %%
# checking the missing values
mv = diabetes.isna().sum().sum()
print(f'there is',mv,'missing values')

# checking the duplicated values 
dv = diabetes.duplicated().sum()
print(f'there is',dv,'duplicated values')
# Out:
# there is 0 missing values
# there is 0 duplicated values

# %%
display(diabetes.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
# None

# %% [markdown]
# ### The data is already clean; no further action is required.

# %% [markdown]
# <h1 style="background-color: #12f7ff;
#            font-family: 'Trebuchet MS', sans-serif;
#            color: #000;
#            font-size: 150%;
#            text-align: center;
#            border-radius: 50px 50px;
#            padding: 20px 20px ;
#            margin: 30px 30px;
#            box-shadow: 0 0 10px rgba(18,247,255,0.6),
#     0 0 20px rgba(18,247,255,0.6),
#     0 0 30px rgba(18,247,255,0.6),
#     0 0 40px rgba(18,247,255,0.6);">
#     🔻🌟 Exploratory Data Analysis (EDA) 🌟🔻</h1>

# %%
display(diabetes.describe())
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
# first let's check if the outcom is balanced or not 


true = len(diabetes.loc[diabetes['Outcome'] == 1])
false = len(diabetes.loc[diabetes['Outcome'] == 0])
print("\nwe have: {} Person affected by diabetes\n".format(true))
print("we have: {} person not afected\n".format(false))


# let's plot this 

plt.figure(figsize=(10,6))
# plt.hist(diabetes['Outcome'],bins=2,edgecolor='black',color='skyblue')
sns.countplot(x='Outcome',data=diabetes)

plt.title('Distribution of Diabetes Outcomes', fontsize=16)
plt.xlabel('Outcome', fontsize=14)
plt.ylabel('Count', fontsize=14)

plt.grid(True, linestyle='--', alpha=0.7)

plt.xticks([0, 1], ['No', 'Yes'])



plt.show()
# Out:
# we have: 268 Person affected by diabetes
#
# we have: 500 person not afected

# %% [markdown]
# ### The dataset is unbalanced.

# %%
print('\n___________________________________________________Histograms__________________________________________________\n')
diabetes.hist(figsize=(12, 10), bins=20,color='skyblue')
plt.tight_layout()
plt.show()



print('\n___________________________________________________Box plots____________________________________________________\n')
plt.figure(figsize=(12, 10))
for i, column in enumerate(diabetes.columns, 1):
    plt.subplot(3, 3, i)
    sns.boxplot(y=diabetes[column],color='skyblue')
    plt.title(column)

plt.tight_layout()
plt.show()



print('\n____________________________________________________Correlation heatmap_________________________________________\n')
plt.figure(figsize=(10, 8))
corr = diabetes.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# ___________________________________________________Histograms__________________________________________________
# ___________________________________________________Box plots____________________________________________________
# ____________________________________________________Correlation heatmap_________________________________________

# %%
corr = diabetes[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness','Insulin','BMI','DiabetesPedigreeFunction', 'Age','Outcome']].corr()['Outcome'].sort_values(ascending = False)
corr = corr.to_frame()
corr.style.background_gradient(cmap="RdYlBu")
# Out:
# <style type="text/css">
# #T_cbfc5_row0_col0 {
#   background-color: #313695;
#   color: #f1f1f1;
# }
# #T_cbfc5_row1_col0 {
#   background-color: #fee99d;
#   color: #000000;
# }
# #T_cbfc5_row2_col0 {
#   background-color: #f88950;
#   color: #f1f1f1;
# }
# #T_cbfc5_row3_col0 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_cbfc5_row4_col0 {
#   background-color: #ea5739;
#   color: #f1f1f1;
# }
# #T_cbfc5_row5_col0 {
#   background-color: #db382b;
#   color: #f1f1f1;
# }
# #T_cbfc5_row6_col0 {
#   background-color: #c62027;
#   color: #f1f1f1;
# }
# #T_cbfc5_row7_col0 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_cbfc5_row8_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cbfc5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cbfc5_level0_col0" class="col_heading level0 col0" >Outcome</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
#  <div style="background-color: #fcf8e8; /* Notepad yellow */
#            font-family: 'Times New Roman', serif; /* Classic font for note-taking */
#            color: #000;
#            font-size: 16px; /* Standard text size */
#            line-height: 1.5; /* Spacing between lines of text */
#            text-align: left;
#            border-radius: 5px;
#            padding: 20px;
#            margin: 20px;
#            width: 90%;
#            box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.2); /* Realistic shadow */
#            background-image: linear-gradient(rgba(0, 0, 0, 0.1) 1px, transparent 1px),
#                              linear-gradient(to right, rgba(0, 0, 0, 0.1) 1px, transparent 1px);
#            background-size: 100% 30px, 30px 100%; /* Size of the lines */
#            border: 1px solid #ddd; /* Border for paper edge */
#            ">
#     <h2 style="text-align: center; color: #d4e157;">📝 Notes 📝</h2>
#     <hr>
#     <ul> Many features, like insulin and Skinteckness, have an excess of zeros that need to be addressed later.</ul>
#     <ul> Outliers in several features (e.g., Insulin, SkinThickness, BMI) Almost all of our features</ul>
#     <ul> Correlations between features, with some significant correlations visible (e.g., Glucose with Outcome) and all of them have a positive correlation </ul>
#     <ul> a significant correlation between the age and pragnacies feature and between insulin and skinteckness</ul>
# </div>

# %% [markdown]
# <h1 style="background-color: #12f7ff;
#            font-family: 'Trebuchet MS', sans-serif;
#            color: #000;
#            font-size: 150%;
#            text-align: center;
#            border-radius: 50px 50px;
#            padding: 20px 20px ;
#            margin: 30px 30px;
#            box-shadow: 0 0 10px rgba(18,247,255,0.6),
#     0 0 20px rgba(18,247,255,0.6),
#     0 0 30px rgba(18,247,255,0.6),
#     0 0 40px rgba(18,247,255,0.6);">
#     🔻🌟 Data Preprocessing for Modeling 🌟🔻</h1>

# %%
print(diabetes.columns)
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
# starting by handling the zero values

# i think that the best solution is to replace zero values with the median of each columns


columns_with_zeros = ['Glucose',
                     'BloodPressure',
                     'SkinThickness',
                     'Insulin',
                     'BMI']

for column in columns_with_zeros:
    diabetes[column] = diabetes[column].replace(0,diabetes[column].median())
    
    
# we can use also this "SimpleImputer(missing_values=0, strategy='mean')"


diabetes.hist(figsize=(12, 10), bins=20,color='skyblue')
plt.tight_layout()
plt.show()

# %%
# handling outliers 

# outliers detection

for feature in diabetes:
    Q1 = diabetes[feature].quantile(0.25)
    Q3 = diabetes[feature].quantile(0.75)
    IQR = Q3-Q1
    lower = Q1-1.5*IQR
    upper = Q3+1.5*IQR
    if diabetes[(diabetes[feature]>upper)].any(axis=None):
        print(feature, "---> theres are outliers here ")
    else:
        print(feature, " ---> everything is good ")
# Out:
# Pregnancies ---> theres are outliers here
# Glucose  ---> everything is good
# BloodPressure ---> theres are outliers here
# SkinThickness ---> theres are outliers here
# Insulin ---> theres are outliers here
# BMI ---> theres are outliers here
# DiabetesPedigreeFunction ---> theres are outliers here
# Age ---> theres are outliers here
# Outcome  ---> everything is good

# %%
columns = ['Pregnancies','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']

# Function to remove outliers using IQR
def remove_outliers(df, columns):
    for column in columns:
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        df = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    return df

# Remove outliers from the specified columns
diabetes = remove_outliers(diabetes,columns)

plt.figure(figsize=(12, 10))
for i, column in enumerate(diabetes.columns, 1):
    plt.subplot(3, 3, i)
    sns.boxplot(y=diabetes[column],color='skyblue')
    plt.title(column)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## feature enginnerint
#
# we can divide people into different categories as per their BMI values. The number obtained from calculating this formula categorises people into skinny, healthy, overweight, and obese. Let us understand the different stages of the BMI chart.
#
#
# - BMI Values 18.5 or below: A person is considered underweight
# - 18.5-24.9: A person is in the healthy and normal weight category
# - 25-29.9: It is the Pre-obese category
# - 30-34.9: Obesity class 1
# - 35-39.9: Obesity class 2
# - 40 and above: Obesity class 3
#
#
# i found the information bellow in this website [here](https://www.healthifyme.com/blog/bmi-type-2-diabetes/)

# %%
# Feature engineering.


NewBMI = pd.Series(["Underweight","Normal", "Overweight","Obesity 1", "Obesity 2", "Obesity 3"], dtype = "category")


diabetes['NewBMI'] = NewBMI
diabetes.loc[diabetes["BMI"]<18.5, "NewBMI"] = NewBMI[0]
diabetes.loc[(diabetes["BMI"]>18.5) & diabetes["BMI"]<=24.9, "NewBMI"] = NewBMI[1]
diabetes.loc[(diabetes["BMI"]>24.9) & diabetes["BMI"]<=29.9, "NewBMI"] = NewBMI[2]
diabetes.loc[(diabetes["BMI"]>29.9) & diabetes["BMI"]<=34.9, "NewBMI"] = NewBMI[3]
diabetes.loc[(diabetes["BMI"]>34.9) & diabetes["BMI"]<=39.9, "NewBMI"] = NewBMI[4]
diabetes.loc[diabetes["BMI"]>39.9, "NewBMI"] = NewBMI[5]

diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35     30.5  33.6
# 1            1       85             66             29     30.5  26.6
# 2            8      183             64             23     30.5  23.3
# 3            1       89             66             23     94.0  28.1
# 5            5      116             74             23     30.5  25.6
#
#    DiabetesPedigreeFunction  Age  Outcome     NewBMI
# 0                     0.627   50        1  Obesity 2
# 1                     0.351   31        0  Obesity 2
# 2                     0.672   32        1  Obesity 2
# 3                     0.167   21        0  Obesity 2
# 5                     0.201   30        0  Obesity 2

# %% [markdown]
# The normal levels of insulin in the body are as follows :
#
# - after nearly eight hours of fasting is less than 25 mIU/L,
# - 30 minutes after glucose administration is 30-230 mIU/L,
# - one hour after glucose ingestion is 18-276 mIU/L,
# - two hours after glucose ingestion is 16-166 mIU/L, and
# - three hours or more after glucose ingestion is less than 25 mIU/L.
#
# this information is [here](https://www.yashodahospitals.com/diagnostics/insulin-test/)

# %%
# if insulin>=16 & insuline<=166->normal
def set_insuline(row):
    if row["Insulin"]>=16 and row["Insulin"]<=166:
        return "Normal"
    else:
        return "Abnormal"
    
diabetes = diabetes.assign(NewInsulinScore=diabetes.apply(set_insuline, axis=1))

diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35     30.5  33.6
# 1            1       85             66             29     30.5  26.6
# 2            8      183             64             23     30.5  23.3
# 3            1       89             66             23     94.0  28.1
# 5            5      116             74             23     30.5  25.6
#
#    DiabetesPedigreeFunction  Age  Outcome     NewBMI NewInsulinScore
# 0                     0.627   50        1  Obesity 2          Normal
# 1                     0.351   31        0  Obesity 2          Normal
# 2                     0.672   32        1  Obesity 2          Normal
# 3                     0.167   21        0  Obesity 2          Normal
# 5                     0.201   30        0  Obesity 2          Normal

# %%
# The glucose variable 
NewGlucose = pd.Series(["Low", "Normal", "Overweight", "Secret", "High"], dtype = "category")
diabetes["NewGlucose"] = NewGlucose
diabetes.loc[diabetes["Glucose"] <= 70, "NewGlucose"] = NewGlucose[0]
diabetes.loc[(diabetes["Glucose"] > 70) & (diabetes["Glucose"] <= 99), "NewGlucose"] = NewGlucose[1]
diabetes.loc[(diabetes["Glucose"] > 99) & (diabetes["Glucose"] <= 126), "NewGlucose"] = NewGlucose[2]
diabetes.loc[diabetes["Glucose"] > 126 ,"NewGlucose"] = NewGlucose[3]
diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35     30.5  33.6
# 1            1       85             66             29     30.5  26.6
# 2            8      183             64             23     30.5  23.3
# 3            1       89             66             23     94.0  28.1
# 5            5      116             74             23     30.5  25.6
#
#    DiabetesPedigreeFunction  Age  Outcome     NewBMI NewInsulinScore  \
# 0                     0.627   50        1  Obesity 2          Normal
# 1                     0.351   31        0  Obesity 2          Normal
# 2                     0.672   32        1  Obesity 2          Normal
# 3                     0.167   21        0  Obesity 2          Normal
# 5                     0.201   30        0  Obesity 2          Normal
#
#    NewGlucose
# 0      Secret
# 1      Normal
# 2      Secret
# 3      Normal
# 5  Overweight

# %%
# One hot encoding
df = pd.get_dummies(diabetes, columns = ["NewBMI", "NewInsulinScore", "NewGlucose"], drop_first=True)
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35     30.5  33.6
# 1            1       85             66             29     30.5  26.6
# 2            8      183             64             23     30.5  23.3
# 3            1       89             66             23     94.0  28.1
# 5            5      116             74             23     30.5  25.6
#
#    DiabetesPedigreeFunction  Age  Outcome  NewBMI_Obesity 1  NewBMI_Obesity 2  \
# 0                     0.627   50        1             False              True
# 1                     0.351   31        0             False              True
# 2                     0.672   32        1             False              True
# 3                     0.167   21        0             False              True
# 5                     0.201   30        0             False              True
#
#    NewBMI_Obesity 3  NewBMI_Overweight  NewBMI_Underweight  \
# ...

# %%
columns_to_convert = [
    'NewBMI_Obesity 1', 'NewBMI_Obesity 2', 'NewBMI_Obesity 3',
    'NewBMI_Overweight', 'NewBMI_Underweight', 'NewInsulinScore_Normal',
    'NewGlucose_Low', 'NewGlucose_Normal', 'NewGlucose_Overweight', 'NewGlucose_Secret'
]

df[columns_to_convert]= df[columns_to_convert].replace({True:1,False:0})
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35     30.5  33.6
# 1            1       85             66             29     30.5  26.6
# 2            8      183             64             23     30.5  23.3
# 3            1       89             66             23     94.0  28.1
# 5            5      116             74             23     30.5  25.6
#
#    DiabetesPedigreeFunction  Age  Outcome  NewBMI_Obesity 1  NewBMI_Obesity 2  \
# 0                     0.627   50        1                 0                 1
# 1                     0.351   31        0                 0                 1
# 2                     0.672   32        1                 0                 1
# 3                     0.167   21        0                 0                 1
# 5                     0.201   30        0                 0                 1
#
#    NewBMI_Obesity 3  NewBMI_Overweight  NewBMI_Underweight  \
# ...

# %%
categorical_df = df[['NewBMI_Obesity 1',
       'NewBMI_Obesity 2', 'NewBMI_Obesity 3', 'NewBMI_Overweight',
       'NewBMI_Underweight', 'NewInsulinScore_Normal', 'NewGlucose_Low',
       'NewGlucose_Normal', 'NewGlucose_Overweight', 'NewGlucose_Secret']]

numerical_df = df.drop(['Outcome','NewBMI_Obesity 1',
       'NewBMI_Obesity 2', 'NewBMI_Obesity 3', 'NewBMI_Overweight',
       'NewBMI_Underweight', 'NewInsulinScore_Normal', 'NewGlucose_Low',
       'NewGlucose_Normal', 'NewGlucose_Overweight', 'NewGlucose_Secret'], axis=1)

# we will applay scaling to the numerical data so it will convert to a numpy array and we will lose the name of each column, the solution is the next :

cols_name = numerical_df.columns
index = numerical_df.index

output =df['Outcome']

# %%
# feature scaling 

transformer = RobustScaler().fit(numerical_df)
numerical_df=transformer.transform(numerical_df)
numerical_df=pd.DataFrame(numerical_df, columns = cols_name, index = index)

print(type(numerical_df))
print(f"min",numerical_df.min().min(),"\n",
    "max",numerical_df.max().max())

numerical_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# min -2.0
#  max 3.158273381294964
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0          0.6  1.014493       0.000000           1.50  0.000000  0.245399
# 1         -0.4 -0.811594      -0.428571           0.75  0.000000 -0.613497
# 2          1.0  2.028986      -0.571429           0.00  0.000000 -1.018405
# 3         -0.4 -0.695652      -0.428571           0.00  0.913669 -0.429448
# 5          0.4  0.086957       0.142857           0.00  0.000000 -0.736196
#
#    DiabetesPedigreeFunction       Age
# 0                  0.858006  1.466667
# 1                  0.024169  0.200000
# 2                  0.993958  0.266667
# 3                 -0.531722 -0.466667
# 5                 -0.429003  0.133333

# %%
# concatenate the numerical with the categorical columns 

X = pd.concat([numerical_df, categorical_df], axis=1)
X.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'NewBMI_Obesity 1',
#        'NewBMI_Obesity 2', 'NewBMI_Obesity 3', 'NewBMI_Overweight',
#        'NewBMI_Underweight', 'NewInsulinScore_Normal', 'NewGlucose_Low',
#        'NewGlucose_Normal', 'NewGlucose_Overweight', 'NewGlucose_Secret'],
#       dtype='object')

# %%
# Train-Test Split

X_train,X_test,y_train,y_test = train_test_split(X,output,test_size=0.2,random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((492, 18), (123, 18), (492,), (123,))

# %%
scaler =StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

print(f"Min",X_train.min(),
     "\nMax",X_train.max())
# Out:
# Min -3.361547262794323
# Max 9.000000000000002

# %% [markdown]
# #### We have 614 samples in the training set and 154 samples in the test set.

# %% [markdown]
# <h1 style="background-color: #12f7ff;
#            font-family: 'Trebuchet MS', sans-serif;
#            color: #000;
#            font-size: 150%;
#            text-align: center;
#            border-radius: 50px 50px;
#            padding: 20px 20px ;
#            margin: 30px 30px;
#            box-shadow: 0 0 10px rgba(18,247,255,0.6),
#     0 0 20px rgba(18,247,255,0.6),
#     0 0 30px rgba(18,247,255,0.6),
#     0 0 40px rgba(18,247,255,0.6);">
#     🔻🌟 Modeling 🌟🔻</h1>

# %% [markdown]
# <div style="background-color: #fcf8e8; /* Notepad yellow */
#            font-family: 'Times New Roman', serif; /* Classic font for note-taking */
#            color: #000;
#            font-size: 16px; /* Standard text size */
#            line-height: 1.5; /* Spacing between lines of text */
#            text-align: left;
#            border-radius: 5px;
#            padding: 20px;
#            margin: 20px;
#            width: 90%;
#            box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.2); /* Realistic shadow */
#            background-image: linear-gradient(rgba(0, 0, 0, 0.1) 1px, transparent 1px),
#                              linear-gradient(to right, rgba(0, 0, 0, 0.1) 1px, transparent 1px);
#            background-size: 100% 30px, 30px 100%; /* Size of the lines */
#            border: 1px solid #ddd; /* Border for paper edge */
#            ">
#     <h2 style="text-align: center; color: #d4e157;">📝 Notes 📝</h2>
#     <hr>
#     <h3>Definitions</hh3>
# <h4>Optuna</h4>
# <p>Optuna is an open-source hyperparameter optimization framework designed to automate the search for the best hyperparameters for machine learning algorithms. It provides a simple and flexible API to minimize the effort required to perform hyperparameter tuning, supporting various optimization algorithms. Optuna is particularly known for its efficiency and effectiveness in finding optimal parameters for complex models, making it widely used in both academia and industry.</p>
#
# <h4>GradientBoostingClassifier with Cross-Validation</h4>
#     <p><code>GradientBoostingClassifier</code> is a part of the sklearn.ensemble module, which implements gradient boosting machines for classification tasks. <code>Cross-Validation</code> is a statistical method used to estimate the skill of machine learning models. It divides the dataset into a fixed number of folds or parts, trains the model on some of these folds, and validates it on the remaining ones. This process is repeated several times, with different sets of folds used for training and validation in each iteration. Combining GradientBoostingClassifier with Cross-Validation allows for a robust assessment of the model's performance, ensuring that the model generalizes well to unseen data.</p>
#     <h4>What we will do first: </h4>
#     <h5> let's find the best model </h5>
# </div>

# %%
classifiers = {
    "Logistic Regression": LogisticRegression( max_iter=1000),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(max_depth=15),
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=100, validation_fraction=0.1, n_iter_no_change=10),
    "AdaBoost": AdaBoostClassifier(),
    "Support Vector Machine": SVC(),
    "K-Nearest Neighbors": KNeighborsClassifier()
}
train_accuracies = {}
test_accuracies = {}

for name, clf in classifiers.items():
    clf.fit(X_train, y_train)
    y_train_pred = clf.predict(X_train)
    y_test_pred = clf.predict(X_test)
    train_accuracies[name] = accuracy_score(y_train, y_train_pred)
    test_accuracies[name] = accuracy_score(y_test, y_test_pred)


results = []
for name in classifiers.keys():
    results.append({
        'Model': name,
        'Train Accuracy': train_accuracies[name],
        'Test Accuracy': test_accuracies[name]
    })
pd.DataFrame(results)
# Out:
#                     Model  Train Accuracy  Test Accuracy
# 0     Logistic Regression        0.786585       0.756098
# 1           Decision Tree        1.000000       0.731707
# 2           Random Forest        1.000000       0.772358
# 3       Gradient Boosting        0.865854       0.780488
# 4                AdaBoost        0.849593       0.674797
# 5  Support Vector Machine        0.827236       0.772358
# 6     K-Nearest Neighbors        0.815041       0.772358

# %% [markdown]
# ### Gradient Boosting	0.869919	0.813008   --- > This is the best because it is less overfitting.

# %%
# def objective(trial):
#     n_estimators = trial.suggest_int('n_estimators', 50, 300)
#     learning_rate = trial.suggest_float('learning_rate', 0.01, 0.3)
#     max_depth = trial.suggest_int('max_depth', 3, 10)
#     min_samples_split = trial.suggest_int('min_samples_split', 2, 20)
#     min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 20)

#     model = GradientBoostingClassifier(
#         n_estimators=n_estimators,
#         learning_rate=learning_rate,
#         max_depth=max_depth,
#         min_samples_split=min_samples_split,
#         min_samples_leaf=min_samples_leaf,
#         random_state=42
#     )
    
#     score = cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy').mean()
#     return score

# study = optuna.create_study(direction='maximize')
# study.optimize(objective, n_trials=100)

# %%
# optuna.visualization.plot_slice(study,params=['n_estimators', 'learning_rate', 'max_depth', 'min_samples_split', 'min_samples_leaf'])

# %%
# optuna.visualization.plot_param_importances(study)

# %%
# best_params = study.best_params
# print("Best parameters:", best_params)

# %%
# best_model = GradientBoostingClassifier(**best_params, random_state=42)
# best_model.fit(X_train, y_train)

# %%
# the best parameters are : learning_rate=0.02179827164513088, max_depth=10,
#                            min_samples_leaf=19, min_samples_split=17,
#                            n_estimators=164, random_state=42

best_model = GradientBoostingClassifier(learning_rate=0.02179827164513088, max_depth=10,
                           min_samples_leaf=19, min_samples_split=17,
                           n_estimators=164, random_state=42)
best_model.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.02179827164513088, max_depth=10,
#                            min_samples_leaf=19, min_samples_split=17,
#                            n_estimators=164, random_state=42)

# %%
y_train_pred = best_model.predict(X_train)
y_test_pred = best_model.predict(X_test)


print(f'Training accuracy : ',accuracy_score(y_train, y_train_pred))
print(f'Testing accuracy : ', accuracy_score(y_test, y_test_pred))
# Out:
# Training accuracy :  0.9491869918699187
# Testing accuracy :  0.8048780487804879

# %% [markdown]
# <h1 style="background-color: #12f7ff;
#            font-family: 'Trebuchet MS', sans-serif;
#            color: #000;
#            font-size: 150%;
#            text-align: center;
#            border-radius: 50px 50px;
#            padding: 20px 20px ;
#            margin: 30px 30px;
#            box-shadow: 0 0 10px rgba(18,247,255,0.6),
#     0 0 20px rgba(18,247,255,0.6),
#     0 0 30px rgba(18,247,255,0.6),
#     0 0 40px rgba(18,247,255,0.6);">
#     🔻🌟 Save the model🌟🔻</h1>

# %%
# Save the model to a pickle file
with open('best_model.pkl', 'wb') as f:
    pickle.dump(best_model, f)

print("Model saved to best_model.pkl")
# Out:
# Model saved to best_model.pkl

# %% [markdown]
# <img style="width: 60%; height: auto; padding: 20px  auto; margin: 20px auto; display: block ; display: block; border-radius: 50px 50px;" src="https://media.giphy.com/media/v1.Y2lkPTc5MGI3NjExaWFsMmxudnF2dm84aGs5NW9lcW9zaXdvM3N6eW55YzY4cjc5bm94MiZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/smaaKxR6ZrQYQxHFfA/giphy.gif">

# %% [markdown]
#  <div align="center">
#   <a href="mailto:hassaneskikri@gmail.com">
#     <img src="https://img.shields.io/badge/Gmail-333333?style=for-the-badge&logo=gmail&logoColor=red" />
#   </a>
#   <a href="https://www.linkedin.com/in/hassane-skikri-3224bb255/" target="_blank">
#     <img src="https://img.shields.io/badge/LinkedIn-0077B5?style=for-the-badge&logo=linkedin&logoColor=white" target="_blank" />
#   </a>
#   <a href="https://hassaneskikri.github.io/skikriPortfolio/" target="_blank">
#      <img src="https://img.shields.io/badge/Portfolio-FF5722?style=for-the-badge&logo=todoist&logoColor=white" target="_blank" />
#   </a>
#    <a href="https://medium.com/@Hassane_01" target="_blank">
#     <img src="https://img.shields.io/badge/Medium-12100E?style=for-the-badge&logo=medium&logoColor=white" target="_blank" />
#   </a>
#     <a href="https://www.kaggle.com/hassaneskikri" target="_blank">
#     <img src="https://img.shields.io/badge/Kaggle-20BEFF?style=for-the-badge&logo=Kaggle&logoColor=white" target="_blank" />
#   </a>
#     <a href="https://github.com/HassaneSkikri" target="_blank">
#     <img src="https://img.shields.io/badge/GitHub-100000?style=for-the-badge&logo=github&logoColor=white" target="_blank" />
#   </a>
